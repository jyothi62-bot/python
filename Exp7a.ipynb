# %% [markdown]
# <a href="https://colab.research.google.com/github/jyothi62-bot/python/blob/main/Exp7a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Q7a="7.a. Write a python program to implement insertion sort using lists."
print(Q7a)

def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key

# Example usage:
nums = [8, 7, 13, 1, -9, 4]
insertion_sort(nums)
print("Insertion sort result:", nums)
# Out:
# 7.a. Write a python program to implement insertion sort using lists.
# Insertion sort result: [-9, 1, 4, 7, 8, 13]

# %% [markdown]
# Result : the program is executed successfully
